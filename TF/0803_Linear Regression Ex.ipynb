# %%
# Lab 2 Linear Regression
import tensorflow as tf
tf.set_random_seed(777)  # for reproducibility

import matplotlib.pyplot as plt
import numpy as np

# X and Y data
x_train = [3, 5, 2, 8]
y_train = [600, 700, 650, 760]

# Try to find values for W and b to compute y_data = x_data * W + b
# We know that W should be 1 and b should be 0
# But let TensorFlow figure it out
W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# Our hypothesis XW+b
hypothesis = x_train * W + b

# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

# Fit the line
for step in range(2000):
    sess.run(train)
    if step % 10== 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
        print ("y", sess.run(W), "x +", sess.run(b))
        x = np.arange(0.0,9, 0.01)
        plt.plot(x, sess.run(W)*x+sess.run(b), 'r--')
        t = np.array([3, 5, 2, 8])
        p = np.array([600, 700, 650, 760])
        plt.scatter(t,p)
        plt.axis([0,9,0,800])
        plt.show()
    
    #    a = sess.run(W)+sess.run(b)
    #    if a < 200 :
    #        plt.axis([0,4,0,200])
    #        plt.show()
    #    else:    
    #        plt.axis([0,4,0,800])
    #        plt.show()
        
        
        
        #x = [x for x in range(5)]
         # y = [sess.run(W)*a + sess.run(b) for a in range(10)]
         #   if y < 500 :
         #       plt.xlim(1, 10)
         #      plt.ylim(100, 500)
         #      plt.plot(y)
         #     plt.show()
         #   else :
         #       plt.xlim(1, 10)
         #       plt.ylim(500, 800)
         #       plt.plot(y)
         #       plt.show()
# Out:
# 0 149956.0 [ 64.55608368] [ 12.54720974]
# y [ 64.55608368] x + [ 12.54720974]
# 10 58425.8 [ 117.21692657] [ 44.20264053]
# y [ 117.21692657] x + [ 44.20264053]
# 20 53988.6 [ 113.55714417] [ 64.96668243]
# y [ 113.55714417] x + [ 64.96668243]
# 30 49892.7 [ 110.0098114] [ 84.9109726]
# y [ 110.0098114] x + [ 84.9109726]
# 40 46111.7 [ 106.60157013] [ 104.07316589]
# y [ 106.60157013] x + [ 104.07316589]
# 50 42621.4 [ 103.32697296] [ 122.48394775]
# y [ 103.32697296] x + [ 122.48394775]
# 60 39399.5 [ 100.18079376] [ 140.17276001]
# y [ 100.18079376] x + [ 140.17276001]
# 70 36425.3 [ 97.15798187] [ 157.16793823]
# y [ 97.15798187] x + [ 157.16793823]
# 80 33679.9 [ 94.25370789] [ 173.49667358]
# y [ 94.25370789] x + [ 173.49667358]
# 90 31145.5 [ 91.46331787] [ 189.18508911]
# y [ 91.46331787] x + [ 189.18508911]
# 100 28805.9 [ 88.78234863] [ 204.25830078]
# y [ 88.78234863] x + [ 204.25830078]
# 110 26646.3 [ 86.20652008] [ 218.74043274]
# y [ 86.20652008] x + [ 218.74043274]
# 120 24652.7 [ 83.73168945] [ 232.6546936]
# y [ 83.73168945] x + [ 232.6546936]
# 130 22812.4 [ 81.35390472] [ 246.02331543]
# y [ 81.35390472] x + [ 246.02331543]
# 140 21113.6 [ 79.06935883] [ 258.8677063]
# y [ 79.06935883] x + [ 258.8677063]
# 150 19545.4 [ 76.87441254] [ 271.20840454]
# y [ 76.87441254] x + [ 271.20840454]
# 160 18097.8 [ 74.76553345] [ 283.06515503]
# y [ 74.76553345] x + [ 283.06515503]
# 170 16761.5 [ 72.73934937] [ 294.45697021]
# y [ 72.73934937] x + [ 294.45697021]
# 180 15528.0 [ 70.79262543] [ 305.40206909]
# y [ 70.79262543] x + [ 305.40206909]
# 190 14389.3 [ 68.92223358] [ 315.91796875]
# y [ 68.92223358] x + [ 315.91796875]
# 200 13338.2 [ 67.12519073] [ 326.02151489]
# y [ 67.12519073] x + [ 326.02151489]
# 210 12367.8 [ 65.39861298] [ 335.72888184]
# y [ 65.39861298] x + [ 335.72888184]
# 220 11472.1 [ 63.73972321] [ 345.05563354]
# y [ 63.73972321] x + [ 345.05563354]
# 230 10645.3 [ 62.14590073] [ 354.01660156]
# y [ 62.14590073] x + [ 354.01660156]
# 240 9881.99 [ 60.61457825] [ 362.62615967]
# y [ 60.61457825] x + [ 362.62615967]
# 250 9177.4 [ 59.14330292] [ 370.89813232]
# y [ 59.14330292] x + [ 370.89813232]
# 260 8526.99 [ 57.72971725] [ 378.84573364]
# y [ 57.72971725] x + [ 378.84573364]
# 270 7926.6 [ 56.37157059] [ 386.48165894]
# y [ 56.37157059] x + [ 386.48165894]
# 280 7372.36 [ 55.06668091] [ 393.81814575]
# y [ 55.06668091] x + [ 393.81814575]
# 290 6860.75 [ 53.81296158] [ 400.86694336]
# y [ 53.81296158] x + [ 400.86694336]
# 300 6388.47 [ 52.60840988] [ 407.63931274]
# y [ 52.60840988] x + [ 407.63931274]
# 310 5952.5 [ 51.45108795] [ 414.14614868]
# y [ 51.45108795] x + [ 414.14614868]
# 320 5550.06 [ 50.33914566] [ 420.39779663]
# y [ 50.33914566] x + [ 420.39779663]
# 330 5178.56 [ 49.2708168] [ 426.40429688]
# y [ 49.2708168] x + [ 426.40429688]
# 340 4835.62 [ 48.24436951] [ 432.17529297]
# y [ 48.24436951] x + [ 432.17529297]
# 350 4519.05 [ 47.2581749] [ 437.7199707]
# y [ 47.2581749] x + [ 437.7199707]
# 360 4226.83 [ 46.31066132] [ 443.04718018]
# y [ 46.31066132] x + [ 443.04718018]
# 370 3957.07 [ 45.4003067] [ 448.16546631]
# y [ 45.4003067] x + [ 448.16546631]
# 380 3708.05 [ 44.5256424] [ 453.08312988]
# y [ 44.5256424] x + [ 453.08312988]
# 390 3478.18 [ 43.68527985] [ 457.80789185]
# y [ 43.68527985] x + [ 457.80789185]
# 400 3265.99 [ 42.87786865] [ 462.34741211]
# y [ 42.87786865] x + [ 462.34741211]
# 410 3070.11 [ 42.10212326] [ 466.7088623]
# y [ 42.10212326] x + [ 466.7088623]
# 420 2889.29 [ 41.35680008] [ 470.89935303]
# y [ 41.35680008] x + [ 470.89935303]
# 430 2722.38 [ 40.64068604] [ 474.92553711]
# y [ 40.64068604] x + [ 474.92553711]
# 440 2568.3 [ 39.95266342] [ 478.79379272]
# y [ 39.95266342] x + [ 478.79379272]
# 450 2426.06 [ 39.29162598] [ 482.51034546]
# y [ 39.29162598] x + [ 482.51034546]
# 460 2294.77 [ 38.65650177] [ 486.08120728]
# y [ 38.65650177] x + [ 486.08120728]
# 470 2173.56 [ 38.04629135] [ 489.51202393]
# y [ 38.04629135] x + [ 489.51202393]
# 480 2061.68 [ 37.45999908] [ 492.80831909]
# y [ 37.45999908] x + [ 492.80831909]
# 490 1958.4 [ 36.89670563] [ 495.9753418]
# y [ 36.89670563] x + [ 495.9753418]
# 500 1863.06 [ 36.35550308] [ 499.01812744]
# y [ 36.35550308] x + [ 499.01812744]
# 510 1775.05 [ 35.83552551] [ 501.94161987]
# y [ 35.83552551] x + [ 501.94161987]
# 520 1693.81 [ 35.33592987] [ 504.75048828]
# y [ 35.33592987] x + [ 504.75048828]
# 530 1618.82 [ 34.85593033] [ 507.44921875]
# y [ 34.85593033] x + [ 507.44921875]
# 540 1549.59 [ 34.39474869] [ 510.04211426]
# y [ 34.39474869] x + [ 510.04211426]
# 550 1485.68 [ 33.95164871] [ 512.53338623]
# y [ 33.95164871] x + [ 512.53338623]
# 560 1426.69 [ 33.52591324] [ 514.92694092]
# y [ 33.52591324] x + [ 514.92694092]
# 570 1372.23 [ 33.11689758] [ 517.2265625]
# y [ 33.11689758] x + [ 517.2265625]
# 580 1321.96 [ 32.72390366] [ 519.43609619]
# y [ 32.72390366] x + [ 519.43609619]
# 590 1275.56 [ 32.34632874] [ 521.55895996]
# y [ 32.34632874] x + [ 521.55895996]
# 600 1232.72 [ 31.98355675] [ 523.59857178]
# y [ 31.98355675] x + [ 523.59857178]
# 610 1193.18 [ 31.63500404] [ 525.55822754]
# y [ 31.63500404] x + [ 525.55822754]
# 620 1156.68 [ 31.30012131] [ 527.44104004]
# y [ 31.30012131] x + [ 527.44104004]
# 630 1122.98 [ 30.97838974] [ 529.24993896]
# y [ 30.97838974] x + [ 529.24993896]
# 640 1091.88 [ 30.66926003] [ 530.98797607]
# y [ 30.66926003] x + [ 530.98797607]
# 650 1063.17 [ 30.37226486] [ 532.65777588]
# y [ 30.37226486] x + [ 532.65777588]
# 660 1036.66 [ 30.08690834] [ 534.262146]
# y [ 30.08690834] x + [ 534.262146]
# 670 1012.2 [ 29.81274033] [ 535.80352783]
# y [ 29.81274033] x + [ 535.80352783]
# 680 989.612 [ 29.54932976] [ 537.2845459]
# y [ 29.54932976] x + [ 537.2845459]
# 690 968.76 [ 29.29623222] [ 538.70758057]
# y [ 29.29623222] x + [ 538.70758057]
# 700 949.516 [ 29.0530777] [ 540.074646]
# y [ 29.0530777] x + [ 540.074646]
# 710 931.748 [ 28.81944084] [ 541.38824463]
# y [ 28.81944084] x + [ 541.38824463]
# 720 915.348 [ 28.5949707] [ 542.65026855]
# y [ 28.5949707] x + [ 542.65026855]
# 730 900.209 [ 28.37930298] [ 543.86279297]
# y [ 28.37930298] x + [ 543.86279297]
# 740 886.234 [ 28.17210197] [ 545.027771]
# y [ 28.17210197] x + [ 545.027771]
# 750 873.333 [ 27.97301865] [ 546.14703369]
# y [ 27.97301865] x + [ 546.14703369]
# 760 861.425 [ 27.78175354] [ 547.22235107]
# y [ 27.78175354] x + [ 547.22235107]
# 770 850.432 [ 27.59797478] [ 548.25567627]
# y [ 27.59797478] x + [ 548.25567627]
# 780 840.284 [ 27.42139816] [ 549.24841309]
# y [ 27.42139816] x + [ 549.24841309]
# 790 830.915 [ 27.25175667] [ 550.20220947]
# y [ 27.25175667] x + [ 550.20220947]
# 800 822.271 [ 27.08878899] [ 551.11846924]
# y [ 27.08878899] x + [ 551.11846924]
# 810 814.287 [ 26.93218231] [ 551.9989624]
# y [ 26.93218231] x + [ 551.9989624]
# 820 806.919 [ 26.7817173] [ 552.84490967]
# y [ 26.7817173] x + [ 552.84490967]
# 830 800.116 [ 26.63715172] [ 553.65771484]
# y [ 26.63715172] x + [ 553.65771484]
# 840 793.836 [ 26.49824524] [ 554.43865967]
# y [ 26.49824524] x + [ 554.43865967]
# 850 788.039 [ 26.36479378] [ 555.18896484]
# y [ 26.36479378] x + [ 555.18896484]
# 860 782.69 [ 26.2365818] [ 555.90985107]
# y [ 26.2365818] x + [ 555.90985107]
# 870 777.75 [ 26.11340332] [ 556.60235596]
# y [ 26.11340332] x + [ 556.60235596]
# 880 773.19 [ 25.99504662] [ 557.26782227]
# y [ 25.99504662] x + [ 557.26782227]
# 890 768.982 [ 25.88134575] [ 557.90710449]
# y [ 25.88134575] x + [ 557.90710449]
# 900 765.098 [ 25.77210045] [ 558.52124023]
# y [ 25.77210045] x + [ 558.52124023]
# 910 761.51 [ 25.66713333] [ 559.1114502]
# y [ 25.66713333] x + [ 559.1114502]
# 920 758.2 [ 25.56627655] [ 559.6784668]
# y [ 25.56627655] x + [ 559.6784668]
# 930 755.145 [ 25.4693737] [ 560.22332764]
# y [ 25.4693737] x + [ 560.22332764]
# 940 752.323 [ 25.3762722] [ 560.74676514]
# y [ 25.3762722] x + [ 560.74676514]
# 950 749.718 [ 25.28681564] [ 561.24969482]
# y [ 25.28681564] x + [ 561.24969482]
# 960 747.314 [ 25.20086861] [ 561.73291016]
# y [ 25.20086861] x + [ 561.73291016]
# 970 745.094 [ 25.11831284] [ 562.19708252]
# y [ 25.11831284] x + [ 562.19708252]
# 980 743.046 [ 25.03899193] [ 562.64306641]
# y [ 25.03899193] x + [ 562.64306641]
# 990 741.156 [ 24.96277237] [ 563.07159424]
# y [ 24.96277237] x + [ 563.07159424]
# 1000 739.41 [ 24.88953209] [ 563.48339844]
# y [ 24.88953209] x + [ 563.48339844]
# 1010 737.799 [ 24.81916428] [ 563.87902832]
# y [ 24.81916428] x + [ 563.87902832]
# 1020 736.311 [ 24.75156975] [ 564.2590332]
# y [ 24.75156975] x + [ 564.2590332]
# 1030 734.938 [ 24.68662262] [ 564.62420654]
# y [ 24.68662262] x + [ 564.62420654]
# 1040 733.67 [ 24.62421227] [ 564.97509766]
# y [ 24.62421227] x + [ 564.97509766]
# 1050 732.5 [ 24.56425095] [ 565.31219482]
# y [ 24.56425095] x + [ 565.31219482]
# 1060 731.42 [ 24.5066433] [ 565.63604736]
# y [ 24.5066433] x + [ 565.63604736]
# 1070 730.423 [ 24.45129013] [ 565.94732666]
# y [ 24.45129013] x + [ 565.94732666]
# 1080 729.502 [ 24.39809036] [ 566.24639893]
# y [ 24.39809036] x + [ 566.24639893]
# 1090 728.652 [ 24.34700012] [ 566.53363037]
# y [ 24.34700012] x + [ 566.53363037]
# 1100 727.868 [ 24.29791069] [ 566.80963135]
# y [ 24.29791069] x + [ 566.80963135]
# 1110 727.144 [ 24.25074387] [ 567.0748291]
# y [ 24.25074387] x + [ 567.0748291]
# 1120 726.476 [ 24.20542145] [ 567.32965088]
# y [ 24.20542145] x + [ 567.32965088]
# 1130 725.859 [ 24.16188431] [ 567.57440186]
# y [ 24.16188431] x + [ 567.57440186]
# 1140 725.289 [ 24.12006569] [ 567.80950928]
# y [ 24.12006569] x + [ 567.80950928]
# 1150 724.764 [ 24.07989693] [ 568.03540039]
# y [ 24.07989693] x + [ 568.03540039]
# 1160 724.278 [ 24.04127502] [ 568.25250244]
# y [ 24.04127502] x + [ 568.25250244]
# 1170 723.83 [ 24.00417519] [ 568.46112061]
# y [ 24.00417519] x + [ 568.46112061]
# 1180 723.416 [ 23.96852875] [ 568.66149902]
# y [ 23.96852875] x + [ 568.66149902]
# 1190 723.035 [ 23.93428421] [ 568.85406494]
# y [ 23.93428421] x + [ 568.85406494]
# 1200 722.684 [ 23.90138054] [ 569.0390625]
# y [ 23.90138054] x + [ 569.0390625]
# 1210 722.357 [ 23.86977577] [ 569.21673584]
# y [ 23.86977577] x + [ 569.21673584]
# 1220 722.058 [ 23.83940506] [ 569.38751221]
# y [ 23.83940506] x + [ 569.38751221]
# 1230 721.779 [ 23.81023216] [ 569.55151367]
# y [ 23.81023216] x + [ 569.55151367]
# 1240 721.524 [ 23.78217506] [ 569.70928955]
# y [ 23.78217506] x + [ 569.70928955]
# 1250 721.289 [ 23.75520134] [ 569.86096191]
# y [ 23.75520134] x + [ 569.86096191]
# 1260 721.07 [ 23.72929955] [ 570.00653076]
# y [ 23.72929955] x + [ 570.00653076]
# 1270 720.869 [ 23.70444298] [ 570.14630127]
# y [ 23.70444298] x + [ 570.14630127]
# 1280 720.682 [ 23.68054771] [ 570.28063965]
# y [ 23.68054771] x + [ 570.28063965]
# 1290 720.511 [ 23.6576004] [ 570.40966797]
# y [ 23.6576004] x + [ 570.40966797]
# 1300 720.353 [ 23.63554192] [ 570.53369141]
# y [ 23.63554192] x + [ 570.53369141]
# 1310 720.207 [ 23.61435127] [ 570.65283203]
# y [ 23.61435127] x + [ 570.65283203]
# 1320 720.072 [ 23.59399223] [ 570.76727295]
# y [ 23.59399223] x + [ 570.76727295]
# 1330 719.948 [ 23.57443237] [ 570.8772583]
# y [ 23.57443237] x + [ 570.8772583]
# 1340 719.833 [ 23.55564117] [ 570.98291016]
# y [ 23.55564117] x + [ 570.98291016]
# 1350 719.725 [ 23.5375843] [ 571.08441162]
# y [ 23.5375843] x + [ 571.08441162]
# 1360 719.629 [ 23.52024078] [ 571.1819458]
# y [ 23.52024078] x + [ 571.1819458]
# 1370 719.538 [ 23.50357628] [ 571.27563477]
# y [ 23.50357628] x + [ 571.27563477]
# 1380 719.455 [ 23.48756027] [ 571.36566162]
# y [ 23.48756027] x + [ 571.36566162]
# 1390 719.377 [ 23.47217941] [ 571.45214844]
# y [ 23.47217941] x + [ 571.45214844]
# 1400 719.306 [ 23.45739555] [ 571.53527832]
# y [ 23.45739555] x + [ 571.53527832]
# 1410 719.24 [ 23.44318008] [ 571.61517334]
# y [ 23.44318008] x + [ 571.61517334]
# 1420 719.18 [ 23.42955589] [ 571.69177246]
# y [ 23.42955589] x + [ 571.69177246]
# 1430 719.124 [ 23.4164505] [ 571.76550293]
# y [ 23.4164505] x + [ 571.76550293]
# 1440 719.073 [ 23.40384865] [ 571.83630371]
# y [ 23.40384865] x + [ 571.83630371]
# 1450 719.025 [ 23.39174271] [ 571.90435791]
# y [ 23.39174271] x + [ 571.90435791]
# 1460 718.981 [ 23.38012314] [ 571.96972656]
# y [ 23.38012314] x + [ 571.96972656]
# 1470 718.94 [ 23.36894798] [ 572.03253174]
# y [ 23.36894798] x + [ 572.03253174]
# 1480 718.903 [ 23.35822105] [ 572.09283447]
# y [ 23.35822105] x + [ 572.09283447]
# 1490 718.869 [ 23.34790993] [ 572.15081787]
# y [ 23.34790993] x + [ 572.15081787]
# 1500 718.836 [ 23.33800507] [ 572.20654297]
# y [ 23.33800507] x + [ 572.20654297]
# 1510 718.807 [ 23.32847595] [ 572.2600708]
# y [ 23.32847595] x + [ 572.2600708]
# 1520 718.779 [ 23.31934166] [ 572.3114624]
# y [ 23.31934166] x + [ 572.3114624]
# 1530 718.754 [ 23.31056404] [ 572.36083984]
# y [ 23.31056404] x + [ 572.36083984]
# 1540 718.731 [ 23.30210686] [ 572.4083252]
# y [ 23.30210686] x + [ 572.4083252]
# 1550 718.71 [ 23.29400063] [ 572.45391846]
# y [ 23.29400063] x + [ 572.45391846]
# 1560 718.691 [ 23.28620338] [ 572.49780273]
# y [ 23.28620338] x + [ 572.49780273]
# 1570 718.671 [ 23.27870941] [ 572.53991699]
# y [ 23.27870941] x + [ 572.53991699]
# 1580 718.655 [ 23.2715168] [ 572.58032227]
# y [ 23.2715168] x + [ 572.58032227]
# 1590 718.64 [ 23.26459885] [ 572.6192627]
# y [ 23.26459885] x + [ 572.6192627]
# 1600 718.626 [ 23.25794983] [ 572.65661621]
# y [ 23.25794983] x + [ 572.65661621]
# 1610 718.612 [ 23.25156784] [ 572.69250488]
# y [ 23.25156784] x + [ 572.69250488]
# 1620 718.599 [ 23.24544144] [ 572.72692871]
# y [ 23.24544144] x + [ 572.72692871]
# 1630 718.588 [ 23.23955536] [ 572.76000977]
# y [ 23.23955536] x + [ 572.76000977]
# 1640 718.578 [ 23.23390198] [ 572.79180908]
# y [ 23.23390198] x + [ 572.79180908]
# 1650 718.568 [ 23.22846222] [ 572.8223877]
# y [ 23.22846222] x + [ 572.8223877]
# 1660 718.56 [ 23.22323799] [ 572.85174561]
# y [ 23.22323799] x + [ 572.85174561]
# 1670 718.552 [ 23.21821594] [ 572.88000488]
# y [ 23.21821594] x + [ 572.88000488]
# 1680 718.544 [ 23.21339035] [ 572.90716553]
# y [ 23.21339035] x + [ 572.90716553]
# 1690 718.536 [ 23.20876122] [ 572.9331665]
# y [ 23.20876122] x + [ 572.9331665]
# 1700 718.529 [ 23.20430565] [ 572.95819092]
# y [ 23.20430565] x + [ 572.95819092]
# 1710 718.523 [ 23.200037] [ 572.98223877]
# y [ 23.200037] x + [ 572.98223877]
# 1720 718.518 [ 23.19592476] [ 573.00531006]
# y [ 23.19592476] x + [ 573.00531006]
# 1730 718.513 [ 23.19198227] [ 573.02752686]
# y [ 23.19198227] x + [ 573.02752686]
# 1740 718.509 [ 23.18818665] [ 573.04882812]
# y [ 23.18818665] x + [ 573.04882812]
# 1750 718.503 [ 23.18453979] [ 573.06933594]
# y [ 23.18453979] x + [ 573.06933594]
# 1760 718.501 [ 23.18103981] [ 573.08905029]
# y [ 23.18103981] x + [ 573.08905029]
# 1770 718.497 [ 23.17766953] [ 573.10797119]
# y [ 23.17766953] x + [ 573.10797119]
# 1780 718.493 [ 23.17444038] [ 573.12609863]
# y [ 23.17444038] x + [ 573.12609863]
# 1790 718.491 [ 23.17133904] [ 573.14355469]
# y [ 23.17133904] x + [ 573.14355469]
# 1800 718.487 [ 23.16835594] [ 573.16033936]
# y [ 23.16835594] x + [ 573.16033936]
# 1810 718.484 [ 23.1654892] [ 573.17645264]
# y [ 23.1654892] x + [ 573.17645264]
# 1820 718.483 [ 23.16273308] [ 573.19195557]
# y [ 23.16273308] x + [ 573.19195557]
# 1830 718.48 [ 23.16008377] [ 573.20684814]
# y [ 23.16008377] x + [ 573.20684814]
# 1840 718.477 [ 23.15754128] [ 573.22113037]
# y [ 23.15754128] x + [ 573.22113037]
# 1850 718.477 [ 23.15509987] [ 573.23486328]
# y [ 23.15509987] x + [ 573.23486328]
# 1860 718.474 [ 23.15275192] [ 573.24804688]
# y [ 23.15275192] x + [ 573.24804688]
# 1870 718.473 [ 23.15049362] [ 573.26074219]
# y [ 23.15049362] x + [ 573.26074219]
# 1880 718.47 [ 23.1483345] [ 573.27294922]
# y [ 23.1483345] x + [ 573.27294922]
# 1890 718.47 [ 23.14625359] [ 573.28460693]
# y [ 23.14625359] x + [ 573.28460693]
# 1900 718.468 [ 23.14425087] [ 573.2958374]
# y [ 23.14425087] x + [ 573.2958374]
# 1910 718.467 [ 23.14231873] [ 573.30670166]
# y [ 23.14231873] x + [ 573.30670166]
# 1920 718.466 [ 23.14048195] [ 573.31707764]
# y [ 23.14048195] x + [ 573.31707764]
# 1930 718.465 [ 23.13871574] [ 573.32696533]
# y [ 23.13871574] x + [ 573.32696533]
# 1940 718.464 [ 23.13700104] [ 573.33660889]
# y [ 23.13700104] x + [ 573.33660889]
# 1950 718.463 [ 23.13537788] [ 573.34576416]
# y [ 23.13537788] x + [ 573.34576416]
# 1960 718.462 [ 23.13379669] [ 573.35461426]
# y [ 23.13379669] x + [ 573.35461426]
# 1970 718.461 [ 23.13228798] [ 573.36315918]
# y [ 23.13228798] x + [ 573.36315918]
# 1980 718.461 [ 23.13083458] [ 573.37127686]
# y [ 23.13083458] x + [ 573.37127686]
# 1990 718.46 [ 23.12943459] [ 573.37921143]
# y [ 23.12943459] x + [ 573.37921143]

# %%
# Lab 2 Linear Regression
import tensorflow as tf
tf.set_random_seed(777)  # for reproducibility

import matplotlib.pyplot as plt
import numpy as np

# X and Y data
x_train = [3]
y_train = [600]

# Try to find values for W and b to compute y_data = x_data * W + b
# We know that W should be 1 and b should be 0
# But let TensorFlow figure it out
W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# Our hypothesis XW+b
hypothesis = x_train * W + b

# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

# Fit the line
for step in range(200):
    sess.run(train)
    if step % 10== 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
        print ("y", sess.run(W), "x +", sess.run(b))
        x = np.arange(0.0,9, 0.01)
        plt.plot(x, sess.run(W)*x+sess.run(b), 'r--')
        t = np.array([3])
        p = np.array([600])
        plt.scatter(t,p)
        plt.axis([0,9,0,800])
        plt.show()
# Out:
# 0 226027.0 [ 37.16350174] [ 13.08678627]
# y [ 37.16350174] x + [ 13.08678627]
# 10 2605.91 [ 164.47589111] [ 55.52424622]
# y [ 164.47589111] x + [ 55.52424622]
# 20 30.0442 [ 178.14593506] [ 60.0809288]
# y [ 178.14593506] x + [ 60.0809288]
# 30 0.346477 [ 179.61373901] [ 60.57020569]
# y [ 179.61373901] x + [ 60.57020569]
# 40 0.00399062 [ 179.7713623] [ 60.62273788]
# y [ 179.7713623] x + [ 60.62273788]
# 50 4.673e-05 [ 179.78826904] [ 60.62837601]
# y [ 179.78826904] x + [ 60.62837601]
# 60 5.36442e-07 [ 179.7901001] [ 60.62898636]
# y [ 179.7901001] x + [ 60.62898636]
# 70 1.49012e-08 [ 179.7902832] [ 60.62905502]
# y [ 179.7902832] x + [ 60.62905502]
# 80 3.72529e-09 [ 179.7902832] [ 60.62906265]
# y [ 179.7902832] x + [ 60.62906265]
# 90 3.72529e-09 [ 179.7902832] [ 60.62906265]
# y [ 179.7902832] x + [ 60.62906265]
# 100 3.72529e-09 [ 179.7902832] [ 60.62906265]
# y [ 179.7902832] x + [ 60.62906265]
# 110 3.72529e-09 [ 179.7902832] [ 60.62906265]
# y [ 179.7902832] x + [ 60.62906265]
# 120 3.72529e-09 [ 179.7902832] [ 60.62906265]
# y [ 179.7902832] x + [ 60.62906265]
# 130 3.72529e-09 [ 179.7902832] [ 60.62906265]
# y [ 179.7902832] x + [ 60.62906265]
# 140 3.72529e-09 [ 179.7902832] [ 60.62906265]
# y [ 179.7902832] x + [ 60.62906265]
# 150 3.72529e-09 [ 179.7902832] [ 60.62906265]
# y [ 179.7902832] x + [ 60.62906265]
# 160 3.72529e-09 [ 179.7902832] [ 60.62906265]
# y [ 179.7902832] x + [ 60.62906265]
# 170 3.72529e-09 [ 179.7902832] [ 60.62906265]
# y [ 179.7902832] x + [ 60.62906265]
# 180 3.72529e-09 [ 179.7902832] [ 60.62906265]
# y [ 179.7902832] x + [ 60.62906265]
# 190 3.72529e-09 [ 179.7902832] [ 60.62906265]
# y [ 179.7902832] x + [ 60.62906265]

# %%
# Lab 2 Linear Regression
import tensorflow as tf
tf.set_random_seed(777)  # for reproducibility

import matplotlib.pyplot as plt
import numpy as np

# X and Y data
x_train = [3, 5]
y_train = [600, 700]

# Try to find values for W and b to compute y_data = x_data * W + b
# We know that W should be 1 and b should be 0
# But let TensorFlow figure it out
W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# Our hypothesis XW+b
hypothesis = x_train * W + b

# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

# Fit the line
for step in range(3000):
    sess.run(train)
    if step % 100== 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
        print ("y", sess.run(W), "x +", sess.run(b))
        x = np.arange(0.0,9, 0.01)
        plt.plot(x, sess.run(W)*x+sess.run(b), 'r--')
        t = np.array([3, 5])
        p = np.array([600, 700])
        plt.scatter(t,p)
        plt.axis([0,9,0,800])
        plt.show()
# Out:
# 0 183040.0 [ 52.21588135] [ 13.31057072]
# y [ 52.21588135] x + [ 13.31057072]
# 100 8073.16 [ 137.44717407] [ 79.5677948]
# y [ 137.44717407] x + [ 79.5677948]
# 200 6459.22 [ 128.21931458] [ 118.6576767]
# y [ 128.21931458] x + [ 118.6576767]
# 300 5167.93 [ 119.96522522] [ 153.62255859]
# y [ 119.96522522] x + [ 153.62255859]
# 400 4134.78 [ 112.58214569] [ 184.89778137]
# y [ 112.58214569] x + [ 184.89778137]
# 500 3308.18 [ 105.9781723] [ 212.87266541]
# y [ 105.9781723] x + [ 212.87266541]
# 600 2646.83 [ 100.07106018] [ 237.89558411]
# y [ 100.07106018] x + [ 237.89558411]
# 700 2117.69 [ 94.78729248] [ 260.27798462]
# y [ 94.78729248] x + [ 260.27798462]
# 800 1694.33 [ 90.06111145] [ 280.29840088]
# y [ 90.06111145] x + [ 280.29840088]
# 900 1355.61 [ 85.83365631] [ 298.20617676]
# y [ 85.83365631] x + [ 298.20617676]
# 1000 1084.61 [ 82.05233765] [ 314.22409058]
# y [ 82.05233765] x + [ 314.22409058]
# 1100 867.778 [ 78.67005157] [ 328.55169678]
# y [ 78.67005157] x + [ 328.55169678]
# 1200 694.298 [ 75.64463806] [ 341.36755371]
# y [ 75.64463806] x + [ 341.36755371]
# 1300 555.496 [ 72.93846893] [ 352.83111572]
# y [ 72.93846893] x + [ 352.83111572]
# 1400 444.444 [ 70.51786804] [ 363.0848999]
# y [ 70.51786804] x + [ 363.0848999]
# 1500 355.593 [ 68.3527298] [ 372.2565918]
# y [ 68.3527298] x + [ 372.2565918]
# 1600 284.506 [ 66.41608429] [ 380.46035767]
# y [ 66.41608429] x + [ 380.46035767]
# 1700 227.629 [ 64.68376923] [ 387.79855347]
# y [ 64.68376923] x + [ 387.79855347]
# 1800 182.122 [ 63.13424301] [ 394.36245728]
# y [ 63.13424301] x + [ 394.36245728]
# 1900 145.713 [ 61.7482605] [ 400.23361206]
# y [ 61.7482605] x + [ 400.23361206]
# 2000 116.583 [ 60.50852966] [ 405.48516846]
# y [ 60.50852966] x + [ 405.48516846]
# 2100 93.2761 [ 59.39960861] [ 410.18261719]
# y [ 59.39960861] x + [ 410.18261719]
# 2200 74.6285 [ 58.40769196] [ 414.38446045]
# y [ 58.40769196] x + [ 414.38446045]
# 2300 59.7095 [ 57.52048111] [ 418.14273071]
# y [ 57.52048111] x + [ 418.14273071]
# 2400 47.7729 [ 56.72688675] [ 421.50445557]
# y [ 56.72688675] x + [ 421.50445557]
# 2500 38.2227 [ 56.01704788] [ 424.51138306]
# y [ 56.01704788] x + [ 424.51138306]
# 2600 30.5818 [ 55.38213348] [ 427.20092773]
# y [ 55.38213348] x + [ 427.20092773]
# 2700 24.468 [ 54.81416702] [ 429.60684204]
# y [ 54.81416702] x + [ 429.60684204]
# 2800 19.5763 [ 54.30615616] [ 431.75881958]
# y [ 54.30615616] x + [ 431.75881958]
# 2900 15.6627 [ 53.85174942] [ 433.68374634]
# y [ 53.85174942] x + [ 433.68374634]

# %%
# Lab 2 Linear Regression
import tensorflow as tf
tf.set_random_seed(777)  # for reproducibility

import matplotlib.pyplot as plt
import numpy as np

# X and Y data
x_train = [3, 5, 2]
y_train = [600, 700, 650]

# Try to find values for W and b to compute y_data = x_data * W + b
# We know that W should be 1 and b should be 0
# But let TensorFlow figure it out
W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# Our hypothesis XW+b
hypothesis = x_train * W + b

# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

# Fit the line
for step in range(3000):
    sess.run(train)
    if step % 100== 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
        print ("y", sess.run(W), "x +", sess.run(b))
        x = np.arange(0.0,9, 0.01)
        plt.plot(x, sess.run(W)*x+sess.run(b), 'r--')
        t = np.array([3, 5, 2])
        p = np.array([600, 700, 650])
        plt.scatter(t,p)
        plt.axis([0,9,0,800])
        plt.show()
# Out:
# 0 243094.0 [ 44.08091736] [ 11.79669952]
# y [ 44.08091736] x + [ 11.79669952]
# 100 23167.5 [ 134.34399414] [ 153.38114929]
# y [ 134.34399414] x + [ 153.38114929]
# 200 14981.1 [ 111.15852356] [ 240.68751526]
# y [ 111.15852356] x + [ 240.68751526]
# 300 9811.41 [ 92.73384857] [ 310.06680298]
# y [ 92.73384857] x + [ 310.06680298]
# 400 6546.79 [ 78.09239197] [ 365.20016479]
# y [ 78.09239197] x + [ 365.20016479]
# 500 4485.2 [ 66.45730591] [ 409.0128479]
# y [ 66.45730591] x + [ 409.0128479]
# 600 3183.34 [ 57.21133804] [ 443.82910156]
# y [ 57.21133804] x + [ 443.82910156]
# 700 2361.22 [ 49.86391449] [ 471.49630737]
# y [ 49.86391449] x + [ 471.49630737]
# 800 1842.05 [ 44.02515793] [ 493.48254395]
# y [ 44.02515793] x + [ 493.48254395]
# 900 1514.2 [ 39.38528442] [ 510.95428467]
# y [ 39.38528442] x + [ 510.95428467]
# 1000 1307.17 [ 35.69817352] [ 524.83831787]
# y [ 35.69817352] x + [ 524.83831787]
# 1100 1176.42 [ 32.76805115] [ 535.87188721]
# y [ 32.76805115] x + [ 535.87188721]
# 1200 1093.86 [ 30.4396553] [ 544.6395874]
# y [ 30.4396553] x + [ 544.6395874]
# 1300 1041.72 [ 28.58934402] [ 551.6071167]
# y [ 28.58934402] x + [ 551.6071167]
# 1400 1008.8 [ 27.11893272] [ 557.14404297]
# y [ 27.11893272] x + [ 557.14404297]
# 1500 988.009 [ 25.95052147] [ 561.54370117]
# y [ 25.95052147] x + [ 561.54370117]
# 1600 974.88 [ 25.02197266] [ 565.04022217]
# y [ 25.02197266] x + [ 565.04022217]
# 1700 966.59 [ 24.28417397] [ 567.81842041]
# y [ 24.28417397] x + [ 567.81842041]
# 1800 961.354 [ 23.69778824] [ 570.02655029]
# y [ 23.69778824] x + [ 570.02655029]
# 1900 958.047 [ 23.2318058] [ 571.78125]
# y [ 23.2318058] x + [ 571.78125]
# 2000 955.959 [ 22.86157036] [ 573.175354]
# y [ 22.86157036] x + [ 573.175354]
# 2100 954.639 [ 22.56731033] [ 574.28344727]
# y [ 22.56731033] x + [ 574.28344727]
# 2200 953.807 [ 22.33350563] [ 575.16381836]
# y [ 22.33350563] x + [ 575.16381836]
# 2300 953.283 [ 22.14769363] [ 575.86352539]
# y [ 22.14769363] x + [ 575.86352539]
# 2400 952.949 [ 22.0000248] [ 576.41955566]
# y [ 22.0000248] x + [ 576.41955566]
# 2500 952.74 [ 21.88269806] [ 576.86138916]
# y [ 21.88269806] x + [ 576.86138916]
# 2600 952.607 [ 21.78944016] [ 577.21252441]
# y [ 21.78944016] x + [ 577.21252441]
# 2700 952.525 [ 21.71534729] [ 577.49157715]
# y [ 21.71534729] x + [ 577.49157715]
# 2800 952.471 [ 21.65647697] [ 577.7131958]
# y [ 21.65647697] x + [ 577.7131958]
# 2900 952.439 [ 21.60973358] [ 577.88928223]
# y [ 21.60973358] x + [ 577.88928223]
